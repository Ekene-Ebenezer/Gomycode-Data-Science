# %% [markdown]
# <a href="https://colab.research.google.com/github/Ekene-Ebenezer/Gomycode-Data-Science/blob/main/API_to_Pandas_Dataframe_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)

# %%
import requests
import json
import webbrowser

# %%
API_KEY = 'k1tm2DfthFM7NpmdHDD0fmvYECdrqEkGAsMlVDpb'

# %%
url  = 'https://api.nasa.gov/planetary/apod'

# %%
params={
    'date': '2024-03-12',
    'hd':'True',
    'api key': API_KEY
}

# %%
response = requests.get(url,params=params)
json_data = json.loads(response.text)
image_url = json_data['hdurl']
image_url
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-536f3f863af2> in <cell line: 3>()
#       1 response = requests.get(url,params=params)
#       2 json_data = json.loads(response.text)
# ----> 3 image_url = json_data['hdurl']
#       4 image_url
#
# KeyError: 'hdurl'

# %%
# !wget $image_url
# Out:
# --2024-03-11 12:58:03--  https://apod.nasa.gov/apod/image/2403/FullPlantonMoon_Horalek_1022.jpg
# Resolving apod.nasa.gov (apod.nasa.gov)... 129.164.179.22, 2001:4d0:2310:150::22
# Connecting to apod.nasa.gov (apod.nasa.gov)|129.164.179.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 165692 (162K) [image/jpeg]
# Saving to: ‘FullPlantonMoon_Horalek_1022.jpg’
#
# FullPlantonMoon_Hor 100%[===================>] 161.81K  --.-KB/s    in 0.04s
#
# 2024-03-11 12:58:03 (3.98 MB/s) - ‘FullPlantonMoon_Horalek_1022.jpg’ saved [165692/165692]

# %%
# !wget $image_url
# Out:
# wget: missing URL
# Usage: wget [OPTION]... [URL]...
#
# Try `wget --help' for more options.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('/content/FullPlantonMoon_Horalek_1022.jpg')
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-865471f591d9> in <cell line: 4>()
#       2 import matplotlib.image as mpimg
#       3
# ----> 4 img = mpimg.imread('/content/FullPlantonMoon_Horalek_1022.jpg')
#       5 plt.imshow(img)
#       6 plt.axis('off')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in imread(fname, format)
#    1561             "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1562             )
# -> 1563     with img_open(fname) as image:
#    1564         return (_pil_png_to_float_array(image)
#    1565                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3225
#    3226     if filename:
# -> 3227         fp = builtins.open(filename, "rb")
#    3228         exclusive_fp = True
#    3229
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/FullPlantonMoon_Horalek_1022.jpg'

# %%
import pandas as pd

# %%
url2= "https://api.nasa.gov/neo/rest/v1/feed"

# %%
params2= {
    'api_key':API_KEY,
    'start_date': '2024-03-11'
}

# %%
response2 = requests.get(url2,params2)

# %%
json_data2 = json.loads(response2.text)
json_data2
# Out:
# {'links': {'next': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-03-18&end_date=2024-03-25&detailed=false&api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo',
#   'previous': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-03-04&end_date=2024-03-11&detailed=false&api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo',
#   'self': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-03-11&end_date=2024-03-18&detailed=false&api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#  'element_count': 59,
#  'near_earth_objects': {'2024-03-16': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54102026?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54102026',
#     'neo_reference_id': '54102026',
#     'name': '(2020 YW3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54102026',
#     'absolute_magnitude_h': 25.73,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0189913123,
#       'estimated_diameter_max': 0.0424658654},
#      'meters': {'estimated_diameter_min': 18.9913123471,
#       'estimated_diameter_max': 42.46586539},
#      'miles': {'estimated_diameter_min': 0.0118006507,
#       'estimated_diameter_max': 0.0263870572},
#      'feet': {'estimated_diameter_min': 62.3074572008,
#       'estimated_diameter_max': 139.3237098062}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-16',
#       'close_approach_date_full': '2024-Mar-16 16:25',
#       'epoch_date_close_approach': 1710606300000,
#       'relative_velocity': {'kilometers_per_second': '9.3983612533',
#        'kilometers_per_hour': '33834.1005117129',
#        'miles_per_hour': '21023.1942874029'},
#       'miss_distance': {'astronomical': '0.3231905344',
#        'lunar': '125.7211178816',
#        'kilometers': '48348615.550401728',
#        'miles': '30042436.6167227264'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54248967?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54248967',
#     'neo_reference_id': '54248967',
#     'name': '(2022 EK1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54248967',
#     'absolute_magnitude_h': 24.67,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0309424699,
#       'estimated_diameter_max': 0.069189466},
#      'meters': {'estimated_diameter_min': 30.9424698617,
#       'estimated_diameter_max': 69.1894660026},
#      'miles': {'estimated_diameter_min': 0.0192267534,
#       'estimated_diameter_max': 0.0429923277},
#      'feet': {'estimated_diameter_min': 101.5172928212,
#       'estimated_diameter_max': 226.9995676399}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-16',
#       'close_approach_date_full': '2024-Mar-16 09:08',
#       'epoch_date_close_approach': 1710580080000,
#       'relative_velocity': {'kilometers_per_second': '11.0108039511',
#        'kilometers_per_hour': '39638.8942241177',
#        'miles_per_hour': '24630.0673583136'},
#       'miss_distance': {'astronomical': '0.1161612759',
#        'lunar': '45.1867363251',
#        'kilometers': '17377479.451122333',
#        'miles': '10797865.0272728754'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54427182?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54427182',
#     'neo_reference_id': '54427182',
#     'name': '(2024 CJ8)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54427182',
#     'absolute_magnitude_h': 23.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0608912622,
#       'estimated_diameter_max': 0.1361570015},
#      'meters': {'estimated_diameter_min': 60.8912622106,
#       'estimated_diameter_max': 136.1570015386},
#      'miles': {'estimated_diameter_min': 0.0378360645,
#       'estimated_diameter_max': 0.0846040122},
#      'feet': {'estimated_diameter_min': 199.7744887109,
#       'estimated_diameter_max': 446.7093369279}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-16',
#       'close_approach_date_full': '2024-Mar-16 01:25',
#       'epoch_date_close_approach': 1710552300000,
#       'relative_velocity': {'kilometers_per_second': '12.0625885021',
#        'kilometers_per_hour': '43425.3186076817',
#        'miles_per_hour': '26982.8042204231'},
#       'miss_distance': {'astronomical': '0.0441512489',
#        'lunar': '17.1748358221',
#        'kilometers': '6604932.793279843',
#        'miles': '4104114.9274061134'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54429352?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54429352',
#     'neo_reference_id': '54429352',
#     'name': '(2024 EK)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54429352',
#     'absolute_magnitude_h': 26.54,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0130784109,
#       'estimated_diameter_max': 0.0292442157},
#      'meters': {'estimated_diameter_min': 13.0784108584,
#       'estimated_diameter_max': 29.2442157171},
#      'miles': {'estimated_diameter_min': 0.0081265452,
#       'estimated_diameter_max': 0.0181715076},
#      'feet': {'estimated_diameter_min': 42.9081734807,
#       'estimated_diameter_max': 95.9455926932}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-16',
#       'close_approach_date_full': '2024-Mar-16 15:30',
#       'epoch_date_close_approach': 1710603000000,
#       'relative_velocity': {'kilometers_per_second': '7.6173119283',
#        'kilometers_per_hour': '27422.3229419766',
#        'miles_per_hour': '17039.1650524743'},
#       'miss_distance': {'astronomical': '0.0178725046',
#        'lunar': '6.9524042894',
#        'kilometers': '2673688.619725202',
#        'miles': '1661353.0703317076'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54429481?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54429481',
#     'neo_reference_id': '54429481',
#     'name': '(2024 EQ)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54429481',
#     'absolute_magnitude_h': 25.875,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0177645813,
#       'estimated_diameter_max': 0.0397228114},
#      'meters': {'estimated_diameter_min': 17.764581329,
#       'estimated_diameter_max': 39.7228114434},
#      'miles': {'estimated_diameter_min': 0.0110383957,
#       'estimated_diameter_max': 0.0246826031},
#      'feet': {'estimated_diameter_min': 58.2827490074,
#       'estimated_diameter_max': 130.324188696}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-16',
#       'close_approach_date_full': '2024-Mar-16 06:31',
#       'epoch_date_close_approach': 1710570660000,
#       'relative_velocity': {'kilometers_per_second': '10.7074326761',
#        'kilometers_per_hour': '38546.7576341069',
#        'miles_per_hour': '23951.4561532594'},
#       'miss_distance': {'astronomical': '0.0177793697',
#        'lunar': '6.9161748133',
#        'kilometers': '2659755.837062539',
#        'miles': '1652695.6406354782'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2024-03-17': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3781962?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '3781962',
#     'neo_reference_id': '3781962',
#     'name': '(2017 SF19)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3781962',
#     'absolute_magnitude_h': 20.32,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.229379698,
#       'estimated_diameter_max': 0.5129085974},
#      'meters': {'estimated_diameter_min': 229.3796979965,
#       'estimated_diameter_max': 512.9085973785},
#      'miles': {'estimated_diameter_min': 0.1425298923,
#       'estimated_diameter_max': 0.3187065281},
#      'feet': {'estimated_diameter_min': 752.5580883747,
#       'estimated_diameter_max': 1682.7710426231}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-17',
#       'close_approach_date_full': '2024-Mar-17 05:13',
#       'epoch_date_close_approach': 1710652380000,
#       'relative_velocity': {'kilometers_per_second': '23.7399394471',
#        'kilometers_per_hour': '85463.7820097389',
#        'miles_per_hour': '53103.8705493292'},
#       'miss_distance': {'astronomical': '0.2578161251',
#        'lunar': '100.2904726639',
#        'kilometers': '38568743.166613537',
#        'miles': '23965505.7084673306'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54016337?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54016337',
#     'neo_reference_id': '54016337',
#     'name': '(2020 FB4)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54016337',
#     'absolute_magnitude_h': 26.8,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0116025908,
#       'estimated_diameter_max': 0.0259441818},
#      'meters': {'estimated_diameter_min': 11.6025908209,
#       'estimated_diameter_max': 25.9441817907},
#      'miles': {'estimated_diameter_min': 0.0072095135,
#       'estimated_diameter_max': 0.0161209622},
#      'feet': {'estimated_diameter_min': 38.066244069,
#       'estimated_diameter_max': 85.1187093863}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-17',
#       'close_approach_date_full': '2024-Mar-17 05:22',
#       'epoch_date_close_approach': 1710652920000,
#       'relative_velocity': {'kilometers_per_second': '11.6638363468',
#        'kilometers_per_hour': '41989.810848534',
#        'miles_per_hour': '26090.8355241905'},
#       'miss_distance': {'astronomical': '0.2831865203',
#        'lunar': '110.1595563967',
#        'kilometers': '42364100.249591761',
#        'miles': '26323831.2428218618'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54194357?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54194357',
#     'neo_reference_id': '54194357',
#     'name': '(2021 RG6)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54194357',
#     'absolute_magnitude_h': 28.92,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.00437074,
#       'estimated_diameter_max': 0.0097732718},
#      'meters': {'estimated_diameter_min': 4.3707400403,
#       'estimated_diameter_max': 9.7732718421},
#      'miles': {'estimated_diameter_min': 0.0027158511,
#       'estimated_diameter_max': 0.0060728277},
#      'feet': {'estimated_diameter_min': 14.3396987538,
#       'estimated_diameter_max': 32.0645411904}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-17',
#       'close_approach_date_full': '2024-Mar-17 21:51',
#       'epoch_date_close_approach': 1710712260000,
#       'relative_velocity': {'kilometers_per_second': '10.669693374',
#        'kilometers_per_hour': '38410.8961465616',
#        'miles_per_hour': '23867.037108401'},
#       'miss_distance': {'astronomical': '0.1440799303',
#        'lunar': '56.0470928867',
#        'kilometers': '21554050.682628461',
#        'miles': '13393066.0494603218'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54265890?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54265890',
#     'neo_reference_id': '54265890',
#     'name': '(2022 FB3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54265890',
#     'absolute_magnitude_h': 23.35,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0568270323,
#       'estimated_diameter_max': 0.1270691073},
#      'meters': {'estimated_diameter_min': 56.827032339,
#       'estimated_diameter_max': 127.0691072695},
#      'miles': {'estimated_diameter_min': 0.0353106699,
#       'estimated_diameter_max': 0.0789570583},
#      'feet': {'estimated_diameter_min': 186.440400779,
#       'estimated_diameter_max': 416.8934098941}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-17',
#       'close_approach_date_full': '2024-Mar-17 01:40',
#       'epoch_date_close_approach': 1710639600000,
#       'relative_velocity': {'kilometers_per_second': '13.0389801241',
#        'kilometers_per_hour': '46940.3284466401',
#        'miles_per_hour': '29166.8946395248'},
#       'miss_distance': {'astronomical': '0.3286911616',
#        'lunar': '127.8608618624',
#        'kilometers': '49171497.663185792',
#        'miles': '30553751.8516042496'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54271308?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54271308',
#     'neo_reference_id': '54271308',
#     'name': '(2022 GT3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54271308',
#     'absolute_magnitude_h': 25.9,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0175612318,
#       'estimated_diameter_max': 0.0392681082},
#      'meters': {'estimated_diameter_min': 17.561231848,
#       'estimated_diameter_max': 39.2681081809},
#      'miles': {'estimated_diameter_min': 0.0109120402,
#       'estimated_diameter_max': 0.0244000636},
#      'feet': {'estimated_diameter_min': 57.6155918963,
#       'estimated_diameter_max': 128.8323800441}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-17',
#       'close_approach_date_full': '2024-Mar-17 05:48',
#       'epoch_date_close_approach': 1710654480000,
#       'relative_velocity': {'kilometers_per_second': '7.1666766918',
#        'kilometers_per_hour': '25800.036090458',
#        'miles_per_hour': '16031.1390918737'},
#       'miss_distance': {'astronomical': '0.2590159429',
#        'lunar': '100.7572017881',
#        'kilometers': '38748233.353881623',
#        'miles': '24077035.7391194774'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54317887?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54317887',
#     'neo_reference_id': '54317887',
#     'name': '(2022 UO4)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54317887',
#     'absolute_magnitude_h': 25.23,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0239086457,
#       'estimated_diameter_max': 0.0534613571},
#      'meters': {'estimated_diameter_min': 23.9086457171,
#       'estimated_diameter_max': 53.4613570733},
#      'miles': {'estimated_diameter_min': 0.0148561391,
#       'estimated_diameter_max': 0.0332193369},
#      'feet': {'estimated_diameter_min': 78.4404412144,
#       'estimated_diameter_max': 175.3981587404}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-17',
#       'close_approach_date_full': '2024-Mar-17 15:47',
#       'epoch_date_close_approach': 1710690420000,
#       'relative_velocity': {'kilometers_per_second': '5.8130622545',
#        'kilometers_per_hour': '20927.0241163253',
#        'miles_per_hour': '13003.2389571689'},
#       'miss_distance': {'astronomical': '0.2136619979',
#        'lunar': '83.1145171831',
#        'kilometers': '31963379.785784473',
#        'miles': '19861123.2263648074'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54402456?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54402456',
#     'neo_reference_id': '54402456',
#     'name': '(2023 VC1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54402456',
#     'absolute_magnitude_h': 26.36,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0142087207,
#       'estimated_diameter_max': 0.0317716653},
#      'meters': {'estimated_diameter_min': 14.2087206728,
#       'estimated_diameter_max': 31.7716652976},
#      'miles': {'estimated_diameter_min': 0.008828887,
#       'estimated_diameter_max': 0.0197419914},
#      'feet': {'estimated_diameter_min': 46.6165391321,
#       'estimated_diameter_max': 104.2377503751}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-17',
#       'close_approach_date_full': '2024-Mar-17 11:44',
#       'epoch_date_close_approach': 1710675840000,
#       'relative_velocity': {'kilometers_per_second': '4.7320997305',
#        'kilometers_per_hour': '17035.5590298288',
#        'miles_per_hour': '10585.2338871733'},
#       'miss_distance': {'astronomical': '0.1700886321',
#        'lunar': '66.1644778869',
#        'kilometers': '25444897.073373627',
#        'miles': '15810725.8882929726'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54422163?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54422163',
#     'neo_reference_id': '54422163',
#     'name': '(2024 BT2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54422163',
#     'absolute_magnitude_h': 22.79,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0735453089,
#       'estimated_diameter_max': 0.1644523102},
#      'meters': {'estimated_diameter_min': 73.545308935,
#       'estimated_diameter_max': 164.452310205},
#      'miles': {'estimated_diameter_min': 0.0456989222,
#       'estimated_diameter_max': 0.1021858964},
#      'feet': {'estimated_diameter_min': 241.2903913664,
#       'estimated_diameter_max': 539.5417174129}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-17',
#       'close_approach_date_full': '2024-Mar-17 07:15',
#       'epoch_date_close_approach': 1710659700000,
#       'relative_velocity': {'kilometers_per_second': '1.7963601024',
#        'kilometers_per_hour': '6466.8963684941',
#        'miles_per_hour': '4018.2779129679'},
#       'miss_distance': {'astronomical': '0.149371548',
#        'lunar': '58.105532172',
#        'kilometers': '22345665.41940276',
#        'miles': '13884952.637807688'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54422166?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54422166',
#     'neo_reference_id': '54422166',
#     'name': '(2024 BW2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54422166',
#     'absolute_magnitude_h': 23.03,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0658498783,
#       'estimated_diameter_max': 0.1472448042},
#      'meters': {'estimated_diameter_min': 65.8498782919,
#       'estimated_diameter_max': 147.2448041708},
#      'miles': {'estimated_diameter_min': 0.0409172047,
#       'estimated_diameter_max': 0.0914936512},
#      'feet': {'estimated_diameter_min': 216.0429146952,
#       'estimated_diameter_max': 483.0866433156}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-17',
#       'close_approach_date_full': '2024-Mar-17 20:54',
#       'epoch_date_close_approach': 1710708840000,
#       'relative_velocity': {'kilometers_per_second': '7.9239958516',
#        'kilometers_per_hour': '28526.3850658894',
#        'miles_per_hour': '17725.1863205245'},
#       'miss_distance': {'astronomical': '0.1334153508',
#        'lunar': '51.8985714612',
#        'kilometers': '19958652.304982796',
#        'miles': '12401731.4663867448'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2024-03-14': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3838919?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '3838919',
#     'neo_reference_id': '3838919',
#     'name': '(2019 ES1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3838919',
#     'absolute_magnitude_h': 23.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0483676488,
#       'estimated_diameter_max': 0.1081533507},
#      'meters': {'estimated_diameter_min': 48.3676488219,
#       'estimated_diameter_max': 108.1533506775},
#      'miles': {'estimated_diameter_min': 0.0300542543,
#       'estimated_diameter_max': 0.0672033557},
#      'feet': {'estimated_diameter_min': 158.6865169607,
#       'estimated_diameter_max': 354.8338390368}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-14',
#       'close_approach_date_full': '2024-Mar-14 08:31',
#       'epoch_date_close_approach': 1710405060000,
#       'relative_velocity': {'kilometers_per_second': '20.0165272111',
#        'kilometers_per_hour': '72059.4979598102',
#        'miles_per_hour': '44774.9697184165'},
#       'miss_distance': {'astronomical': '0.1975429235',
#        'lunar': '76.8441972415',
#        'kilometers': '29552000.589172945',
#        'miles': '18362761.673538841'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3892316?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '3892316',
#     'neo_reference_id': '3892316',
#     'name': '(2019 VO1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3892316',
#     'absolute_magnitude_h': 21.99,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1063053145,
#       'estimated_diameter_max': 0.2377059096},
#      'meters': {'estimated_diameter_min': 106.3053144865,
#       'estimated_diameter_max': 237.7059095613},
#      'miles': {'estimated_diameter_min': 0.0660550396,
#       'estimated_diameter_max': 0.1477035587},
#      'feet': {'estimated_diameter_min': 348.7707279799,
#       'estimated_diameter_max': 779.8750563251}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-14',
#       'close_approach_date_full': '2024-Mar-14 21:18',
#       'epoch_date_close_approach': 1710451080000,
#       'relative_velocity': {'kilometers_per_second': '8.7042545185',
#        'kilometers_per_hour': '31335.3162667721',
#        'miles_per_hour': '19470.5469325396'},
#       'miss_distance': {'astronomical': '0.2568861199',
#        'lunar': '99.9287006411',
#        'kilometers': '38429616.369604613',
#        'miles': '23879056.3255171394'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54016204?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54016204',
#     'neo_reference_id': '54016204',
#     'name': '(2020 FM)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54016204',
#     'absolute_magnitude_h': 24.1,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.040230458,
#       'estimated_diameter_max': 0.0899580388},
#      'meters': {'estimated_diameter_min': 40.2304579834,
#       'estimated_diameter_max': 89.9580388169},
#      'miles': {'estimated_diameter_min': 0.0249980399,
#       'estimated_diameter_max': 0.0558973165},
#      'feet': {'estimated_diameter_min': 131.9896957704,
#       'estimated_diameter_max': 295.1379320721}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-14',
#       'close_approach_date_full': '2024-Mar-14 16:42',
#       'epoch_date_close_approach': 1710434520000,
#       'relative_velocity': {'kilometers_per_second': '11.2988379492',
#        'kilometers_per_hour': '40675.8166172417',
#        'miles_per_hour': '25274.3706086411'},
#       'miss_distance': {'astronomical': '0.2394769931',
#        'lunar': '93.1565503159',
#        'kilometers': '35825248.081764697',
#        'miles': '22260776.9120669386'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54103335?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54103335',
#     'neo_reference_id': '54103335',
#     'name': '(2020 YB5)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54103335',
#     'absolute_magnitude_h': 25.23,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0239086457,
#       'estimated_diameter_max': 0.0534613571},
#      'meters': {'estimated_diameter_min': 23.9086457171,
#       'estimated_diameter_max': 53.4613570733},
#      'miles': {'estimated_diameter_min': 0.0148561391,
#       'estimated_diameter_max': 0.0332193369},
#      'feet': {'estimated_diameter_min': 78.4404412144,
#       'estimated_diameter_max': 175.3981587404}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-14',
#       'close_approach_date_full': '2024-Mar-14 15:48',
#       'epoch_date_close_approach': 1710431280000,
#       'relative_velocity': {'kilometers_per_second': '18.172712751',
#        'kilometers_per_hour': '65421.7659034542',
#        'miles_per_hour': '40650.5411526213'},
#       'miss_distance': {'astronomical': '0.4687908522',
#        'lunar': '182.3596415058',
#        'kilometers': '70130112.964604814',
#        'miles': '43576831.5116778732'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54425752?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54425752',
#     'neo_reference_id': '54425752',
#     'name': '(2024 CS1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54425752',
#     'absolute_magnitude_h': 22.67,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0777239702,
#       'estimated_diameter_max': 0.1737960809},
#      'meters': {'estimated_diameter_min': 77.7239702031,
#       'estimated_diameter_max': 173.7960808552},
#      'miles': {'estimated_diameter_min': 0.0482954211,
#       'estimated_diameter_max': 0.1079918446},
#      'feet': {'estimated_diameter_min': 254.9999104011,
#       'estimated_diameter_max': 570.1971339131}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-14',
#       'close_approach_date_full': '2024-Mar-14 21:07',
#       'epoch_date_close_approach': 1710450420000,
#       'relative_velocity': {'kilometers_per_second': '4.2752031666',
#        'kilometers_per_hour': '15390.7313997614',
#        'miles_per_hour': '9563.2019633684'},
#       'miss_distance': {'astronomical': '0.1696999087',
#        'lunar': '66.0132644843',
#        'kilometers': '25386744.880714469',
#        'miles': '15774591.7913349122'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54427454?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54427454',
#     'neo_reference_id': '54427454',
#     'name': '(2024 CA9)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54427454',
#     'absolute_magnitude_h': 22.11,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.100590039,
#       'estimated_diameter_max': 0.2249261651},
#      'meters': {'estimated_diameter_min': 100.5900390178,
#       'estimated_diameter_max': 224.9261651032},
#      'miles': {'estimated_diameter_min': 0.0625037331,
#       'estimated_diameter_max': 0.1397625961},
#      'feet': {'estimated_diameter_min': 330.0198236112,
#       'estimated_diameter_max': 737.9467595171}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-14',
#       'close_approach_date_full': '2024-Mar-14 23:34',
#       'epoch_date_close_approach': 1710459240000,
#       'relative_velocity': {'kilometers_per_second': '8.5688772201',
#        'kilometers_per_hour': '30847.9579925049',
#        'miles_per_hour': '19167.7214537317'},
#       'miss_distance': {'astronomical': '0.3022095467',
#        'lunar': '117.5595136663',
#        'kilometers': '45209904.479985529',
#        'miles': '28092131.9943931402'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2024-03-15': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3748567?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '3748567',
#     'neo_reference_id': '3748567',
#     'name': '(2016 FG15)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3748567',
#     'absolute_magnitude_h': 19.96,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2707415909,
#       'estimated_diameter_max': 0.6053966017},
#      'meters': {'estimated_diameter_min': 270.7415909448,
#       'estimated_diameter_max': 605.396601689},
#      'miles': {'estimated_diameter_min': 0.1682309731,
#       'estimated_diameter_max': 0.3761758918},
#      'feet': {'estimated_diameter_min': 888.2598412353,
#       'estimated_diameter_max': 1986.2093866853}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-15',
#       'close_approach_date_full': '2024-Mar-15 16:00',
#       'epoch_date_close_approach': 1710518400000,
#       'relative_velocity': {'kilometers_per_second': '27.7020616178',
#        'kilometers_per_hour': '99727.4218239871',
#        'miles_per_hour': '61966.7416327991'},
#       'miss_distance': {'astronomical': '0.4231991794',
#        'lunar': '164.6244807866',
#        'kilometers': '63309695.823987878',
#        'miles': '39338820.8196655964'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3771063?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '3771063',
#     'neo_reference_id': '3771063',
#     'name': '(2017 EH4)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3771063',
#     'absolute_magnitude_h': 24.06,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.040978398,
#       'estimated_diameter_max': 0.0916304836},
#      'meters': {'estimated_diameter_min': 40.9783980394,
#       'estimated_diameter_max': 91.6304836251},
#      'miles': {'estimated_diameter_min': 0.0254627882,
#       'estimated_diameter_max': 0.0569365252},
#      'feet': {'estimated_diameter_min': 134.4435674236,
#       'estimated_diameter_max': 300.6249558967}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-15',
#       'close_approach_date_full': '2024-Mar-15 18:17',
#       'epoch_date_close_approach': 1710526620000,
#       'relative_velocity': {'kilometers_per_second': '9.8545225121',
#        'kilometers_per_hour': '35476.2810437084',
#        'miles_per_hour': '22043.5814074087'},
#       'miss_distance': {'astronomical': '0.1402544626',
#        'lunar': '54.5589859514',
#        'kilometers': '20981768.862954662',
#        'miles': '13037466.6160798556'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3986767?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '3986767',
#     'neo_reference_id': '3986767',
#     'name': '(2020 BP1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3986767',
#     'absolute_magnitude_h': 27.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0096506147,
#       'estimated_diameter_max': 0.0215794305},
#      'meters': {'estimated_diameter_min': 9.6506146958,
#       'estimated_diameter_max': 21.5794304844},
#      'miles': {'estimated_diameter_min': 0.0059966121,
#       'estimated_diameter_max': 0.0134088323},
#      'feet': {'estimated_diameter_min': 31.6621227185,
#       'estimated_diameter_max': 70.7986587106}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-15',
#       'close_approach_date_full': '2024-Mar-15 06:04',
#       'epoch_date_close_approach': 1710482640000,
#       'relative_velocity': {'kilometers_per_second': '14.0675556481',
#        'kilometers_per_hour': '50643.2003331766',
#        'miles_per_hour': '31467.7152292452'},
#       'miss_distance': {'astronomical': '0.3274248265',
#        'lunar': '127.3682575085',
#        'kilometers': '48982056.629519555',
#        'miles': '30436038.651717659'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54016212?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54016212',
#     'neo_reference_id': '54016212',
#     'name': '(2020 FU)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54016212',
#     'absolute_magnitude_h': 26.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0139493823,
#       'estimated_diameter_max': 0.0311917671},
#      'meters': {'estimated_diameter_min': 13.9493822934,
#       'estimated_diameter_max': 31.1917670523},
#      'miles': {'estimated_diameter_min': 0.0086677416,
#       'estimated_diameter_max': 0.0193816595},
#      'feet': {'estimated_diameter_min': 45.7656914036,
#       'estimated_diameter_max': 102.3351970157}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-15',
#       'close_approach_date_full': '2024-Mar-15 21:29',
#       'epoch_date_close_approach': 1710538140000,
#       'relative_velocity': {'kilometers_per_second': '15.4865567999',
#        'kilometers_per_hour': '55751.6044797581',
#        'miles_per_hour': '34641.8789057697'},
#       'miss_distance': {'astronomical': '0.0380893802',
#        'lunar': '14.8167688978',
#        'kilometers': '5698090.147540174',
#        'miles': '3540629.0365314412'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54053823?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54053823',
#     'neo_reference_id': '54053823',
#     'name': '(2020 RF2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54053823',
#     'absolute_magnitude_h': 25.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0211132445,
#       'estimated_diameter_max': 0.0472106499},
#      'meters': {'estimated_diameter_min': 21.113244479,
#       'estimated_diameter_max': 47.2106498806},
#      'miles': {'estimated_diameter_min': 0.0131191578,
#       'estimated_diameter_max': 0.0293353287},
#      'feet': {'estimated_diameter_min': 69.2691770164,
#       'estimated_diameter_max': 154.8905885541}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-15',
#       'close_approach_date_full': '2024-Mar-15 07:01',
#       'epoch_date_close_approach': 1710486060000,
#       'relative_velocity': {'kilometers_per_second': '21.46089629',
#        'kilometers_per_hour': '77259.2266439629',
#        'miles_per_hour': '48005.878911078'},
#       'miss_distance': {'astronomical': '0.1675054404',
#        'lunar': '65.1596163156',
#        'kilometers': '25058457.097251948',
#        'miles': '15570603.2217669624'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54203701?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54203701',
#     'neo_reference_id': '54203701',
#     'name': '(2021 TQ3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54203701',
#     'absolute_magnitude_h': 27.1,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0101054342,
#       'estimated_diameter_max': 0.0225964377},
#      'meters': {'estimated_diameter_min': 10.1054341542,
#       'estimated_diameter_max': 22.5964377109},
#      'miles': {'estimated_diameter_min': 0.0062792237,
#       'estimated_diameter_max': 0.0140407711},
#      'feet': {'estimated_diameter_min': 33.1543125905,
#       'estimated_diameter_max': 74.1352966996}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-15',
#       'close_approach_date_full': '2024-Mar-15 01:43',
#       'epoch_date_close_approach': 1710466980000,
#       'relative_velocity': {'kilometers_per_second': '15.9286752519',
#        'kilometers_per_hour': '57343.2309068954',
#        'miles_per_hour': '35630.8536710096'},
#       'miss_distance': {'astronomical': '0.4200825373',
#        'lunar': '163.4121070097',
#        'kilometers': '62843452.804275551',
#        'miles': '39049110.8412465638'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54384215?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54384215',
#     'neo_reference_id': '54384215',
#     'name': '(2023 SG)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54384215',
#     'absolute_magnitude_h': 26.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0127219879,
#       'estimated_diameter_max': 0.0284472297},
#      'meters': {'estimated_diameter_min': 12.7219878539,
#       'estimated_diameter_max': 28.4472296503},
#      'miles': {'estimated_diameter_min': 0.0079050743,
#       'estimated_diameter_max': 0.0176762835},
#      'feet': {'estimated_diameter_min': 41.7388066307,
#       'estimated_diameter_max': 93.330808926}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-15',
#       'close_approach_date_full': '2024-Mar-15 22:50',
#       'epoch_date_close_approach': 1710543000000,
#       'relative_velocity': {'kilometers_per_second': '10.4948718618',
#        'kilometers_per_hour': '37781.5387024944',
#        'miles_per_hour': '23475.9788676694'},
#       'miss_distance': {'astronomical': '0.2399456584',
#        'lunar': '93.3388611176',
#        'kilometers': '35895359.412387608',
#        'miles': '22304342.0727726704'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54402466?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54402466',
#     'neo_reference_id': '54402466',
#     'name': '(2023 VN1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54402466',
#     'absolute_magnitude_h': 27.13,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0099667824,
#       'estimated_diameter_max': 0.022286403},
#      'meters': {'estimated_diameter_min': 9.9667823997,
#       'estimated_diameter_max': 22.2864029626},
#      'miles': {'estimated_diameter_min': 0.0061930695,
#       'estimated_diameter_max': 0.0138481245},
#      'feet': {'estimated_diameter_min': 32.6994183682,
#       'estimated_diameter_max': 73.118122296}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-15',
#       'close_approach_date_full': '2024-Mar-15 11:19',
#       'epoch_date_close_approach': 1710501540000,
#       'relative_velocity': {'kilometers_per_second': '5.8462060566',
#        'kilometers_per_hour': '21046.3418039223',
#        'miles_per_hour': '13077.3783281094'},
#       'miss_distance': {'astronomical': '0.2341558388',
#        'lunar': '91.0866212932',
#        'kilometers': '35029214.732543356',
#        'miles': '21766144.7252600728'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2024-03-18': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3746497?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '3746497',
#     'neo_reference_id': '3746497',
#     'name': '(2016 EU155)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3746497',
#     'absolute_magnitude_h': 24.01,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0419329075,
#       'estimated_diameter_max': 0.0937648318},
#      'meters': {'estimated_diameter_min': 41.9329075486,
#       'estimated_diameter_max': 93.7648317729},
#      'miles': {'estimated_diameter_min': 0.0260558927,
#       'estimated_diameter_max': 0.0582627473},
#      'feet': {'estimated_diameter_min': 137.5751604018,
#       'estimated_diameter_max': 307.6274106738}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-18',
#       'close_approach_date_full': '2024-Mar-18 19:07',
#       'epoch_date_close_approach': 1710788820000,
#       'relative_velocity': {'kilometers_per_second': '24.6725454273',
#        'kilometers_per_hour': '88821.1635381025',
#        'miles_per_hour': '55190.0168662171'},
#       'miss_distance': {'astronomical': '0.4689293284',
#        'lunar': '182.4135087476',
#        'kilometers': '70150828.709170508',
#        'miles': '43589703.6784606904'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3762123?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '3762123',
#     'neo_reference_id': '3762123',
#     'name': '(2016 UW41)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3762123',
#     'absolute_magnitude_h': 21.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1677084622,
#       'estimated_diameter_max': 0.3750075218},
#      'meters': {'estimated_diameter_min': 167.7084621628,
#       'estimated_diameter_max': 375.0075217981},
#      'miles': {'estimated_diameter_min': 0.1042091748,
#       'estimated_diameter_max': 0.2330187988},
#      'feet': {'estimated_diameter_min': 550.2246310023,
#       'estimated_diameter_max': 1230.3396778159}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-18',
#       'close_approach_date_full': '2024-Mar-18 11:06',
#       'epoch_date_close_approach': 1710759960000,
#       'relative_velocity': {'kilometers_per_second': '11.1155934822',
#        'kilometers_per_hour': '40016.136535956',
#        'miles_per_hour': '24864.4710603555'},
#       'miss_distance': {'astronomical': '0.3099127907',
#        'lunar': '120.5560755823',
#        'kilometers': '46362293.374475809',
#        'miles': '28808193.2492278042'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3771062?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '3771062',
#     'neo_reference_id': '3771062',
#     'name': '(2017 EG4)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3771062',
#     'absolute_magnitude_h': 21.88,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1118291378,
#       'estimated_diameter_max': 0.250057554},
#      'meters': {'estimated_diameter_min': 111.8291378246,
#       'estimated_diameter_max': 250.057554041},
#      'miles': {'estimated_diameter_min': 0.0694873832,
#       'estimated_diameter_max': 0.1553785124},
#      'feet': {'estimated_diameter_min': 366.8935085404,
#       'estimated_diameter_max': 820.3988255998}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-18',
#       'close_approach_date_full': '2024-Mar-18 04:45',
#       'epoch_date_close_approach': 1710737100000,
#       'relative_velocity': {'kilometers_per_second': '23.2213663931',
#        'kilometers_per_hour': '83596.9190151445',
#        'miles_per_hour': '51943.8744847158'},
#       'miss_distance': {'astronomical': '0.1493764809',
#        'lunar': '58.1074510701',
#        'kilometers': '22346403.370735683',
#        'miles': '13885411.1795031054'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3781972?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '3781972',
#     'neo_reference_id': '3781972',
#     'name': '(2017 SM19)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3781972',
#     'absolute_magnitude_h': 22.24,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0947447113,
#       'estimated_diameter_max': 0.2118556149},
#      'meters': {'estimated_diameter_min': 94.7447112647,
#       'estimated_diameter_max': 211.8556148964},
#      'miles': {'estimated_diameter_min': 0.058871616,
#       'estimated_diameter_max': 0.1316409353},
#      'feet': {'estimated_diameter_min': 310.8422385057,
#       'estimated_diameter_max': 695.0643755769}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-18',
#       'close_approach_date_full': '2024-Mar-18 16:24',
#       'epoch_date_close_approach': 1710779040000,
#       'relative_velocity': {'kilometers_per_second': '12.2040983438',
#        'kilometers_per_hour': '43934.7540375529',
#        'miles_per_hour': '27299.3475851673'},
#       'miss_distance': {'astronomical': '0.3828994036',
#        'lunar': '148.9478680004',
#        'kilometers': '57280935.202830332',
#        'miles': '35592722.6785573016'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3826762?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '3826762',
#     'neo_reference_id': '3826762',
#     'name': '(2018 PO20)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3826762',
#     'absolute_magnitude_h': 26.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0133215567,
#       'estimated_diameter_max': 0.0297879063},
#      'meters': {'estimated_diameter_min': 13.3215566698,
#       'estimated_diameter_max': 29.7879062798},
#      'miles': {'estimated_diameter_min': 0.008277629,
#       'estimated_diameter_max': 0.0185093411},
#      'feet': {'estimated_diameter_min': 43.7058959846,
#       'estimated_diameter_max': 97.7293544391}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-18',
#       'close_approach_date_full': '2024-Mar-18 05:46',
#       'epoch_date_close_approach': 1710740760000,
#       'relative_velocity': {'kilometers_per_second': '7.514283228',
#        'kilometers_per_hour': '27051.419620878',
#        'miles_per_hour': '16808.7001527617'},
#       'miss_distance': {'astronomical': '0.4454621581',
#        'lunar': '173.2847795009',
#        'kilometers': '66640190.017363247',
#        'miles': '41408293.9486849286'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3843427?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '3843427',
#     'neo_reference_id': '3843427',
#     'name': '(2019 OV3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3843427',
#     'absolute_magnitude_h': 24.26,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0373727432,
#       'estimated_diameter_max': 0.0835679943},
#      'meters': {'estimated_diameter_min': 37.3727431914,
#       'estimated_diameter_max': 83.5679942816},
#      'miles': {'estimated_diameter_min': 0.0232223388,
#       'estimated_diameter_max': 0.0519267282},
#      'feet': {'estimated_diameter_min': 122.613990772,
#       'estimated_diameter_max': 274.1732183587}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-18',
#       'close_approach_date_full': '2024-Mar-18 02:35',
#       'epoch_date_close_approach': 1710729300000,
#       'relative_velocity': {'kilometers_per_second': '16.3951952505',
#        'kilometers_per_hour': '59022.7029018677',
#        'miles_per_hour': '36674.4122558855'},
#       'miss_distance': {'astronomical': '0.4137224567',
#        'lunar': '160.9380356563',
#        'kilometers': '61891998.293487229',
#        'miles': '38457904.4228486002'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54016198?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54016198',
#     'neo_reference_id': '54016198',
#     'name': '(2020 FD)',
# ...
#       'estimated_diameter_max': 101.3969822901}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-13',
#       'close_approach_date_full': '2024-Mar-13 08:18',
#       'epoch_date_close_approach': 1710317880000,
#       'relative_velocity': {'kilometers_per_second': '12.2910055341',
#        'kilometers_per_hour': '44247.619922787',
#        'miles_per_hour': '27493.7502792451'},
#       'miss_distance': {'astronomical': '0.1503615217',
#        'lunar': '58.4906319413',
#        'kilometers': '22493763.376278779',
#        'miles': '13976976.4410099902'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54249059?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54249059',
#     'neo_reference_id': '54249059',
#     'name': '(2022 EX1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54249059',
#     'absolute_magnitude_h': 22.46,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0856160085,
#       'estimated_diameter_max': 0.1914432149},
#      'meters': {'estimated_diameter_min': 85.6160084723,
#       'estimated_diameter_max': 191.4432149063},
#      'miles': {'estimated_diameter_min': 0.0531993048,
#       'estimated_diameter_max': 0.1189572619},
#      'feet': {'estimated_diameter_min': 280.8924252363,
#       'estimated_diameter_max': 628.0945571932}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-13',
#       'close_approach_date_full': '2024-Mar-13 18:39',
#       'epoch_date_close_approach': 1710355140000,
#       'relative_velocity': {'kilometers_per_second': '20.7280742134',
#        'kilometers_per_hour': '74621.0671681367',
#        'miles_per_hour': '46366.6292078903'},
#       'miss_distance': {'astronomical': '0.3169047684',
#        'lunar': '123.2759549076',
#        'kilometers': '47408278.345483308',
#        'miles': '29458138.1718653304'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54322243?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54322243',
#     'neo_reference_id': '54322243',
#     'name': '(2022 UN20)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54322243',
#     'absolute_magnitude_h': 27.51,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.008366715,
#       'estimated_diameter_max': 0.0187085435},
#      'meters': {'estimated_diameter_min': 8.3667150189,
#       'estimated_diameter_max': 18.7085435306},
#      'miles': {'estimated_diameter_min': 0.0051988341,
#       'estimated_diameter_max': 0.0116249464},
#      'feet': {'estimated_diameter_min': 27.4498533025,
#       'estimated_diameter_max': 61.3797379569}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-13',
#       'close_approach_date_full': '2024-Mar-13 16:07',
#       'epoch_date_close_approach': 1710346020000,
#       'relative_velocity': {'kilometers_per_second': '9.3247369907',
#        'kilometers_per_hour': '33569.0531663569',
#        'miles_per_hour': '20858.5041743955'},
#       'miss_distance': {'astronomical': '0.1570307207',
#        'lunar': '61.0849503523',
#        'kilometers': '23491461.341284909',
#        'miles': '14596917.2094293842'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54336802?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54336802',
#     'neo_reference_id': '54336802',
#     'name': '(2022 YO4)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54336802',
#     'absolute_magnitude_h': 24.12,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0398616229,
#       'estimated_diameter_max': 0.0891332986},
#      'meters': {'estimated_diameter_min': 39.8616229277,
#       'estimated_diameter_max': 89.1332985597},
#      'miles': {'estimated_diameter_min': 0.0247688565,
#       'estimated_diameter_max': 0.0553848469},
#      'feet': {'estimated_diameter_min': 130.779606966,
#       'estimated_diameter_max': 292.4320912466}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-13',
#       'close_approach_date_full': '2024-Mar-13 15:35',
#       'epoch_date_close_approach': 1710344100000,
#       'relative_velocity': {'kilometers_per_second': '13.3235203212',
#        'kilometers_per_hour': '47964.6731562055',
#        'miles_per_hour': '29803.3826064211'},
#       'miss_distance': {'astronomical': '0.3551348231',
#        'lunar': '138.1474461859',
#        'kilometers': '53127413.098586797',
#        'miles': '33011843.7199279186'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54429760?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54429760',
#     'neo_reference_id': '54429760',
#     'name': '(2024 EL1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54429760',
#     'absolute_magnitude_h': 26.272,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.014796363,
#       'estimated_diameter_max': 0.0330856734},
#      'meters': {'estimated_diameter_min': 14.7963629749,
#       'estimated_diameter_max': 33.0856734315},
#      'miles': {'estimated_diameter_min': 0.0091940309,
#       'estimated_diameter_max': 0.020558478},
#      'feet': {'estimated_diameter_min': 48.5444995024,
#       'estimated_diameter_max': 108.5488008211}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-13',
#       'close_approach_date_full': '2024-Mar-13 13:09',
#       'epoch_date_close_approach': 1710335340000,
#       'relative_velocity': {'kilometers_per_second': '7.8816156016',
#        'kilometers_per_hour': '28373.8161656966',
#        'miles_per_hour': '17630.3859391796'},
#       'miss_distance': {'astronomical': '0.0217907527',
#        'lunar': '8.4766028003',
#        'kilometers': '3259850.189616749',
#        'miles': '2025576.9805751762'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2024-03-11': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3770320?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '3770320',
#     'neo_reference_id': '3770320',
#     'name': '(2017 DR109)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3770320',
#     'absolute_magnitude_h': 27.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0080270317,
#       'estimated_diameter_max': 0.0179489885},
#      'meters': {'estimated_diameter_min': 8.0270316728,
#       'estimated_diameter_max': 17.948988478},
#      'miles': {'estimated_diameter_min': 0.0049877647,
#       'estimated_diameter_max': 0.0111529809},
#      'feet': {'estimated_diameter_min': 26.3354065935,
#       'estimated_diameter_max': 58.8877593581}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-11',
#       'close_approach_date_full': '2024-Mar-11 00:11',
#       'epoch_date_close_approach': 1710115860000,
#       'relative_velocity': {'kilometers_per_second': '18.3326471008',
#        'kilometers_per_hour': '65997.5295627194',
#        'miles_per_hour': '41008.2982996798'},
#       'miss_distance': {'astronomical': '0.3738661035',
#        'lunar': '145.4339142615',
#        'kilometers': '55929572.748799545',
#        'miles': '34753024.986921921'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3838913?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '3838913',
#     'neo_reference_id': '3838913',
#     'name': '(2019 EM1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3838913',
#     'absolute_magnitude_h': 22.31,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0917392059,
#       'estimated_diameter_max': 0.2051351006},
#      'meters': {'estimated_diameter_min': 91.7392059155,
#       'estimated_diameter_max': 205.1351006288},
#      'miles': {'estimated_diameter_min': 0.0570040821,
#       'estimated_diameter_max': 0.1274650026},
#      'feet': {'estimated_diameter_min': 300.9816563357,
#       'estimated_diameter_max': 673.0154435471}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-11',
#       'close_approach_date_full': '2024-Mar-11 16:08',
#       'epoch_date_close_approach': 1710173280000,
#       'relative_velocity': {'kilometers_per_second': '16.1741676177',
#        'kilometers_per_hour': '58227.0034236746',
#        'miles_per_hour': '36179.9955440049'},
#       'miss_distance': {'astronomical': '0.1940563797',
#        'lunar': '75.4879317033',
#        'kilometers': '29030421.063031239',
#        'miles': '18038667.1844555382'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54211501?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54211501',
#     'neo_reference_id': '54211501',
#     'name': '(2021 UO)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54211501',
#     'absolute_magnitude_h': 20.43,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2180494405,
#       'estimated_diameter_max': 0.4875733714},
#      'meters': {'estimated_diameter_min': 218.0494404829,
#       'estimated_diameter_max': 487.5733713755},
#      'miles': {'estimated_diameter_min': 0.1354895989,
#       'estimated_diameter_max': 0.3029639533},
#      'feet': {'estimated_diameter_min': 715.3853263138,
#       'estimated_diameter_max': 1599.6502197435}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-11',
#       'close_approach_date_full': '2024-Mar-11 02:18',
#       'epoch_date_close_approach': 1710123480000,
#       'relative_velocity': {'kilometers_per_second': '25.1943403321',
#        'kilometers_per_hour': '90699.6251956349',
#        'miles_per_hour': '56357.219888921'},
#       'miss_distance': {'astronomical': '0.3746721387',
#        'lunar': '145.7474619543',
#        'kilometers': '56050153.897864569',
#        'miles': '34827950.6386022922'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54340710?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54340710',
#     'neo_reference_id': '54340710',
#     'name': '(2023 CD)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54340710',
#     'absolute_magnitude_h': 24.06,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.040978398,
#       'estimated_diameter_max': 0.0916304836},
#      'meters': {'estimated_diameter_min': 40.9783980394,
#       'estimated_diameter_max': 91.6304836251},
#      'miles': {'estimated_diameter_min': 0.0254627882,
#       'estimated_diameter_max': 0.0569365252},
#      'feet': {'estimated_diameter_min': 134.4435674236,
#       'estimated_diameter_max': 300.6249558967}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-11',
#       'close_approach_date_full': '2024-Mar-11 08:17',
#       'epoch_date_close_approach': 1710145020000,
#       'relative_velocity': {'kilometers_per_second': '5.847167548',
#        'kilometers_per_hour': '21049.8031727718',
#        'miles_per_hour': '13079.5290881037'},
#       'miss_distance': {'astronomical': '0.1342003748',
#        'lunar': '52.2039457972',
#        'kilometers': '20076090.223281676',
#        'miles': '12474704.0050360888'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54390821?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54390821',
#     'neo_reference_id': '54390821',
#     'name': '(2023 TQ)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54390821',
#     'absolute_magnitude_h': 25.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0192555078,
#       'estimated_diameter_max': 0.0430566244},
#      'meters': {'estimated_diameter_min': 19.2555078188,
#       'estimated_diameter_max': 43.0566244241},
#      'miles': {'estimated_diameter_min': 0.0119648141,
#       'estimated_diameter_max': 0.0267541378},
#      'feet': {'estimated_diameter_min': 63.1742402722,
#       'estimated_diameter_max': 141.2618956756}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-11',
#       'close_approach_date_full': '2024-Mar-11 07:40',
#       'epoch_date_close_approach': 1710142800000,
#       'relative_velocity': {'kilometers_per_second': '12.5829653665',
#        'kilometers_per_hour': '45298.6753195418',
#        'miles_per_hour': '28146.835228412'},
#       'miss_distance': {'astronomical': '0.3116415994',
#        'lunar': '121.2285821666',
#        'kilometers': '46620919.473633278',
#        'miles': '28968896.0553561164'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54426892?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54426892',
#     'neo_reference_id': '54426892',
#     'name': '(2024 CU6)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54426892',
#     'absolute_magnitude_h': 26.48,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0134448195,
#       'estimated_diameter_max': 0.0300635304},
#      'meters': {'estimated_diameter_min': 13.444819516,
#       'estimated_diameter_max': 30.0635303831},
#      'miles': {'estimated_diameter_min': 0.0083542209,
#       'estimated_diameter_max': 0.0186806059},
#      'feet': {'estimated_diameter_min': 44.110301661,
#       'estimated_diameter_max': 98.633633022}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-11',
#       'close_approach_date_full': '2024-Mar-11 03:50',
#       'epoch_date_close_approach': 1710129000000,
#       'relative_velocity': {'kilometers_per_second': '4.1510022422',
#        'kilometers_per_hour': '14943.6080720558',
#        'miles_per_hour': '9285.3769156615'},
#       'miss_distance': {'astronomical': '0.0544039989',
#        'lunar': '21.1631555721',
#        'kilometers': '8138722.354922343',
#        'miles': '5057167.5673726134'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54427946?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#     'id': '54427946',
#     'neo_reference_id': '54427946',
#     'name': '(2024 DA1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54427946',
#     'absolute_magnitude_h': 24.32,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0363542322,
#       'estimated_diameter_max': 0.0812905344},
#      'meters': {'estimated_diameter_min': 36.3542321843,
#       'estimated_diameter_max': 81.290534434},
#      'miles': {'estimated_diameter_min': 0.0225894656,
#       'estimated_diameter_max': 0.0505115807},
#      'feet': {'estimated_diameter_min': 119.2724191197,
#       'estimated_diameter_max': 266.7012369924}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-03-11',
#       'close_approach_date_full': '2024-Mar-11 07:38',
#       'epoch_date_close_approach': 1710142680000,
#       'relative_velocity': {'kilometers_per_second': '9.9437528606',
#        'kilometers_per_hour': '35797.5102982118',
#        'miles_per_hour': '22243.1807739083'},
#       'miss_distance': {'astronomical': '0.0240318475',
#        'lunar': '9.3483886775',
#        'kilometers': '3595113.198164825',
#        'miles': '2233899.754031585'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}]}}

# %%
all_object_near_earth = json_data2['near_earth_objects']['2024-03-16']
all_object_near_earth
# Out:
# [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54102026?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#   'id': '54102026',
#   'neo_reference_id': '54102026',
#   'name': '(2020 YW3)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54102026',
#   'absolute_magnitude_h': 25.73,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0189913123,
#     'estimated_diameter_max': 0.0424658654},
#    'meters': {'estimated_diameter_min': 18.9913123471,
#     'estimated_diameter_max': 42.46586539},
#    'miles': {'estimated_diameter_min': 0.0118006507,
#     'estimated_diameter_max': 0.0263870572},
#    'feet': {'estimated_diameter_min': 62.3074572008,
#     'estimated_diameter_max': 139.3237098062}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-03-16',
#     'close_approach_date_full': '2024-Mar-16 16:25',
#     'epoch_date_close_approach': 1710606300000,
#     'relative_velocity': {'kilometers_per_second': '9.3983612533',
#      'kilometers_per_hour': '33834.1005117129',
#      'miles_per_hour': '21023.1942874029'},
#     'miss_distance': {'astronomical': '0.3231905344',
#      'lunar': '125.7211178816',
#      'kilometers': '48348615.550401728',
#      'miles': '30042436.6167227264'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54248967?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#   'id': '54248967',
#   'neo_reference_id': '54248967',
#   'name': '(2022 EK1)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54248967',
#   'absolute_magnitude_h': 24.67,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0309424699,
#     'estimated_diameter_max': 0.069189466},
#    'meters': {'estimated_diameter_min': 30.9424698617,
#     'estimated_diameter_max': 69.1894660026},
#    'miles': {'estimated_diameter_min': 0.0192267534,
#     'estimated_diameter_max': 0.0429923277},
#    'feet': {'estimated_diameter_min': 101.5172928212,
#     'estimated_diameter_max': 226.9995676399}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-03-16',
#     'close_approach_date_full': '2024-Mar-16 09:08',
#     'epoch_date_close_approach': 1710580080000,
#     'relative_velocity': {'kilometers_per_second': '11.0108039511',
#      'kilometers_per_hour': '39638.8942241177',
#      'miles_per_hour': '24630.0673583136'},
#     'miss_distance': {'astronomical': '0.1161612759',
#      'lunar': '45.1867363251',
#      'kilometers': '17377479.451122333',
#      'miles': '10797865.0272728754'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54427182?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#   'id': '54427182',
#   'neo_reference_id': '54427182',
#   'name': '(2024 CJ8)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54427182',
#   'absolute_magnitude_h': 23.2,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0608912622,
#     'estimated_diameter_max': 0.1361570015},
#    'meters': {'estimated_diameter_min': 60.8912622106,
#     'estimated_diameter_max': 136.1570015386},
#    'miles': {'estimated_diameter_min': 0.0378360645,
#     'estimated_diameter_max': 0.0846040122},
#    'feet': {'estimated_diameter_min': 199.7744887109,
#     'estimated_diameter_max': 446.7093369279}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-03-16',
#     'close_approach_date_full': '2024-Mar-16 01:25',
#     'epoch_date_close_approach': 1710552300000,
#     'relative_velocity': {'kilometers_per_second': '12.0625885021',
#      'kilometers_per_hour': '43425.3186076817',
#      'miles_per_hour': '26982.8042204231'},
#     'miss_distance': {'astronomical': '0.0441512489',
#      'lunar': '17.1748358221',
#      'kilometers': '6604932.793279843',
#      'miles': '4104114.9274061134'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54429352?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#   'id': '54429352',
#   'neo_reference_id': '54429352',
#   'name': '(2024 EK)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54429352',
#   'absolute_magnitude_h': 26.54,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0130784109,
#     'estimated_diameter_max': 0.0292442157},
#    'meters': {'estimated_diameter_min': 13.0784108584,
#     'estimated_diameter_max': 29.2442157171},
#    'miles': {'estimated_diameter_min': 0.0081265452,
#     'estimated_diameter_max': 0.0181715076},
#    'feet': {'estimated_diameter_min': 42.9081734807,
#     'estimated_diameter_max': 95.9455926932}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-03-16',
#     'close_approach_date_full': '2024-Mar-16 15:30',
#     'epoch_date_close_approach': 1710603000000,
#     'relative_velocity': {'kilometers_per_second': '7.6173119283',
#      'kilometers_per_hour': '27422.3229419766',
#      'miles_per_hour': '17039.1650524743'},
#     'miss_distance': {'astronomical': '0.0178725046',
#      'lunar': '6.9524042894',
#      'kilometers': '2673688.619725202',
#      'miles': '1661353.0703317076'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54429481?api_key=xkcZFg7LfKMVNXKaGqgtYOl0aOeiGfUadWkjhPgo'},
#   'id': '54429481',
#   'neo_reference_id': '54429481',
#   'name': '(2024 EQ)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54429481',
#   'absolute_magnitude_h': 25.875,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0177645813,
#     'estimated_diameter_max': 0.0397228114},
#    'meters': {'estimated_diameter_min': 17.764581329,
#     'estimated_diameter_max': 39.7228114434},
#    'miles': {'estimated_diameter_min': 0.0110383957,
#     'estimated_diameter_max': 0.0246826031},
#    'feet': {'estimated_diameter_min': 58.2827490074,
#     'estimated_diameter_max': 130.324188696}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-03-16',
#     'close_approach_date_full': '2024-Mar-16 06:31',
#     'epoch_date_close_approach': 1710570660000,
#     'relative_velocity': {'kilometers_per_second': '10.7074326761',
#      'kilometers_per_hour': '38546.7576341069',
#      'miles_per_hour': '23951.4561532594'},
#     'miss_distance': {'astronomical': '0.0177793697',
#      'lunar': '6.9161748133',
#      'kilometers': '2659755.837062539',
#      'miles': '1652695.6406354782'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False}]

# %%
df = pd.DataFrame([near_earth_objects['id'], near_earth_objects['name'], near_earth_objects['estimated_diameter']['kilometers']['estimated_diameter_min'], near_earth_objects['absolute_magnitude_h'], near_earth_objects['close_approach_data'][0]['relative_velocity']['kilometers_per_second']] for near_earth_objects in all_object_near_earth )
df.columns = columns=('Asteroid ID', 'Asteroid name','Minimal estimated diameter in Kilometre', 'Absolute_magnitude', 'Relative velocity(km/s)')
df
# Out:
#   Asteroid ID Asteroid name  Minimal estimated diameter in Kilometre  \
# 0    54102026    (2020 YW3)                                 0.018991
# 1    54248967    (2022 EK1)                                 0.030942
# 2    54427182    (2024 CJ8)                                 0.060891
# 3    54429352     (2024 EK)                                 0.013078
# 4    54429481     (2024 EQ)                                 0.017765
#
#    Absolute_magnitude Relative velocity(km/s)
# 0              25.730            9.3983612533
# 1              24.670           11.0108039511
# 2              23.200           12.0625885021
# 3              26.540            7.6173119283
# 4              25.875           10.7074326761
